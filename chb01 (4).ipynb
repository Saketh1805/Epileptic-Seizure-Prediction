edf’
#
# physionet.org/files 100%[===================>]  40.44M  3.48MB/s    in 11s
#
# 2022-12-12 06:37:19 (3.68 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_20.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:37:19--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_21.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_21.edf’
#
# physionet.org/files 100%[===================>]  40.44M  3.77MB/s    in 11s
#
# 2022-12-12 06:37:30 (3.65 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_21.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:37:30--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_22.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_22.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.40MB/s    in 10s
#
# 2022-12-12 06:37:41 (3.88 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_22.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:37:41--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_23.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_23.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.98MB/s    in 9.1s
#
# 2022-12-12 06:37:50 (4.42 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_23.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:37:50--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_24.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_24.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.07MB/s    in 9.8s
#
# 2022-12-12 06:38:00 (4.12 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_24.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:38:00--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_25.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_25.edf’
#
# physionet.org/files 100%[===================>]  40.44M  3.94MB/s    in 10s
#
# 2022-12-12 06:38:11 (3.86 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_25.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:38:11--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_26.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_26.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.14MB/s    in 9.6s
#
# 2022-12-12 06:38:21 (4.19 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_26.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:38:21--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_27.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_27.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.21MB/s    in 9.4s
#
# 2022-12-12 06:38:31 (4.32 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_27.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:38:31--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_28.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_28.edf’
#
# physionet.org/files 100%[===================>]  40.44M  3.99MB/s    in 9.9s
#
# 2022-12-12 06:38:41 (4.09 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_28.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:38:41--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_29.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_29.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.23MB/s    in 9.8s
#
# 2022-12-12 06:38:51 (4.12 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_29.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:38:51--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_30.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_30.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.43MB/s    in 9.5s
#
# 2022-12-12 06:39:00 (4.27 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_30.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:39:00--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_31.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_31.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.35MB/s    in 9.4s
#
# 2022-12-12 06:39:10 (4.31 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_31.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:39:10--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_32.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_32.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.02MB/s    in 10s
#
# 2022-12-12 06:39:20 (4.06 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_32.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:39:20--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_33.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_33.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.23MB/s    in 9.3s
#
# 2022-12-12 06:39:30 (4.32 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_33.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:39:30--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_34.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_34.edf’
#
# physionet.org/files 100%[===================>]  40.44M  4.11MB/s    in 9.3s
#
# 2022-12-12 06:39:39 (4.36 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_34.edf’ saved [42399744/42399744]
#
# --2022-12-12 06:39:39--  https://physionet.org/files/chbmit/1.0.0/chb02/chb02_35.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_35.edf’
#
# physionet.org/files 100%[===================>]  40.44M  3.99MB/s    in 11s
#
# 2022-12-12 06:39:50 (3.81 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb02/chb02_35.edf’ saved [42399744/42399744]
#
# FINISHED --2022-12-12 06:39:50--
# Total wall clock time: 6m 50s
# Downloaded: 41 files, 1.4G in 6m 38s (3.58 MB/s)

# %%
# !wget -r -N -c -np https://physionet.org/files/chbmit/1.0.0/chb03/
# Out:
# --2022-02-13 16:45:12--  https://physionet.org/files/chbmit/1.0.0/chb03/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/index.html’
#
# physionet.org/files     [ <=>                ]   5.56K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2022-02-13 16:45:12 (202 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/index.html’ saved [5691]
#
# Loading robots.txt; please ignore errors.
# --2022-02-13 16:45:12--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2022-02-13 16:45:12--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03-summary.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4935 (4.8K) [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03-summary.txt’
#
# physionet.org/files 100%[===================>]   4.82K  --.-KB/s    in 0s
#
# 2022-02-13 16:45:12 (183 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03-summary.txt’ saved [4935/4935]
#
# --2022-02-13 16:45:12--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_01.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_01.edf’
#
# physionet.org/files 100%[===================>]  40.44M  40.0MB/s    in 1.0s
#
# 2022-02-13 16:45:14 (40.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_01.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:14--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_01.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_01.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:45:14 (11.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_01.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:45:14--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_02.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_02.edf’
#
# physionet.org/files 100%[===================>]  40.44M  58.3MB/s    in 0.7s
#
# 2022-02-13 16:45:14 (58.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_02.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:14--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_02.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_02.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:45:14 (7.71 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_02.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:45:14--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_03.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_03.edf’
#
# physionet.org/files 100%[===================>]  40.44M  55.3MB/s    in 0.7s
#
# 2022-02-13 16:45:15 (55.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_03.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:15--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_03.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_03.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:45:15 (8.06 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_03.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:45:15--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_04.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_04.edf’
#
# physionet.org/files 100%[===================>]  40.44M  53.4MB/s    in 0.8s
#
# 2022-02-13 16:45:16 (53.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_04.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:16--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_04.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_04.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:45:16 (10.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_04.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:45:16--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_05.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_05.edf’
#
# physionet.org/files 100%[===================>]  40.44M  38.4MB/s    in 1.1s
#
# 2022-02-13 16:45:17 (38.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_05.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:17--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_06.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_06.edf’
#
# physionet.org/files 100%[===================>]  40.44M  38.1MB/s    in 1.1s
#
# 2022-02-13 16:45:18 (38.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_06.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:18--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_07.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_07.edf’
#
# physionet.org/files 100%[===================>]  40.44M  39.4MB/s    in 1.0s
#
# 2022-02-13 16:45:19 (39.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_07.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:19--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_08.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_08.edf’
#
# physionet.org/files 100%[===================>]  40.44M  42.6MB/s    in 0.9s
#
# 2022-02-13 16:45:20 (42.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_08.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:20--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_09.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_09.edf’
#
# physionet.org/files 100%[===================>]  40.44M  42.7MB/s    in 0.9s
#
# 2022-02-13 16:45:21 (42.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_09.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:21--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_10.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_10.edf’
#
# physionet.org/files 100%[===================>]  40.44M  43.2MB/s    in 0.9s
#
# 2022-02-13 16:45:22 (43.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_10.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:22--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_11.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_11.edf’
#
# physionet.org/files 100%[===================>]  40.44M  41.6MB/s    in 1.0s
#
# 2022-02-13 16:45:24 (41.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_11.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:24--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_12.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_12.edf’
#
# physionet.org/files 100%[===================>]  40.44M  43.4MB/s    in 0.9s
#
# 2022-02-13 16:45:25 (43.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_12.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:25--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_13.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_13.edf’
#
# physionet.org/files 100%[===================>]  40.44M  37.4MB/s    in 1.1s
#
# 2022-02-13 16:45:26 (37.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_13.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:26--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_14.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_14.edf’
#
# physionet.org/files 100%[===================>]  40.44M  33.3MB/s    in 1.2s
#
# 2022-02-13 16:45:27 (33.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_14.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:27--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_15.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_15.edf’
#
# physionet.org/files 100%[===================>]  40.44M  35.1MB/s    in 1.2s
#
# 2022-02-13 16:45:28 (35.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_15.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:28--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_16.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_16.edf’
#
# physionet.org/files 100%[===================>]  40.44M  39.1MB/s    in 1.0s
#
# 2022-02-13 16:45:29 (39.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_16.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:29--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_17.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_17.edf’
#
# physionet.org/files 100%[===================>]  40.44M  30.6MB/s    in 1.3s
#
# 2022-02-13 16:45:31 (30.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_17.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:31--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_18.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_18.edf’
#
# physionet.org/files 100%[===================>]  40.44M  31.4MB/s    in 1.3s
#
# 2022-02-13 16:45:32 (31.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_18.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:32--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_19.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_19.edf’
#
# physionet.org/files 100%[===================>]  40.44M  31.9MB/s    in 1.3s
#
# 2022-02-13 16:45:33 (31.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_19.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:33--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_20.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42470400 (41M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_20.edf’
#
# physionet.org/files 100%[===================>]  40.50M  31.3MB/s    in 1.3s
#
# 2022-02-13 16:45:35 (31.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_20.edf’ saved [42470400/42470400]
#
# --2022-02-13 16:45:35--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_21.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_21.edf’
#
# physionet.org/files 100%[===================>]  40.44M  13.3MB/s    in 3.1s
#
# 2022-02-13 16:45:38 (13.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_21.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:38--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_22.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_22.edf’
#
# physionet.org/files 100%[===================>]  40.44M  10.9MB/s    in 3.7s
#
# 2022-02-13 16:45:42 (10.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_22.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:42--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_23.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_23.edf’
#
# physionet.org/files 100%[===================>]  40.44M  11.8MB/s    in 3.5s
#
# 2022-02-13 16:45:45 (11.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_23.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:45--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_24.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_24.edf’
#
# physionet.org/files 100%[===================>]  40.44M  10.4MB/s    in 3.8s
#
# 2022-02-13 16:45:49 (10.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_24.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:49--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_25.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_25.edf’
#
# physionet.org/files 100%[===================>]  40.44M  12.4MB/s    in 3.2s
#
# 2022-02-13 16:45:52 (12.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_25.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:52--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_26.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_26.edf’
#
# physionet.org/files 100%[===================>]  40.44M  12.6MB/s    in 3.2s
#
# 2022-02-13 16:45:56 (12.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_26.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:56--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_27.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_27.edf’
#
# physionet.org/files 100%[===================>]  40.44M  13.6MB/s    in 3.0s
#
# 2022-02-13 16:45:59 (13.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_27.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:45:59--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_28.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_28.edf’
#
# physionet.org/files 100%[===================>]  40.44M  16.7MB/s    in 2.4s
#
# 2022-02-13 16:46:01 (16.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_28.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:01--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_29.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_29.edf’
#
# physionet.org/files 100%[===================>]  40.44M  21.2MB/s    in 1.9s
#
# 2022-02-13 16:46:03 (21.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_29.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:03--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_30.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_30.edf’
#
# physionet.org/files 100%[===================>]  40.44M  27.8MB/s    in 1.5s
#
# 2022-02-13 16:46:05 (27.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_30.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:05--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_31.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_31.edf’
#
# physionet.org/files 100%[===================>]  40.44M  32.9MB/s    in 1.2s
#
# 2022-02-13 16:46:06 (32.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_31.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:06--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_32.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_32.edf’
#
# physionet.org/files 100%[===================>]  40.44M  39.9MB/s    in 1.0s
#
# 2022-02-13 16:46:07 (39.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_32.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:07--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_33.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_33.edf’
#
# physionet.org/files 100%[===================>]  40.44M  46.2MB/s    in 0.9s
#
# 2022-02-13 16:46:08 (46.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_33.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:08--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_34.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_34.edf’
#
# physionet.org/files 100%[===================>]  40.44M  52.5MB/s    in 0.8s
#
# 2022-02-13 16:46:09 (52.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_34.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:09--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_34.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_34.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:46:09 (11.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_34.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:46:09--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_35.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_35.edf’
#
# physionet.org/files 100%[===================>]  40.44M  50.5MB/s    in 0.8s
#
# 2022-02-13 16:46:10 (50.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_35.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:10--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_35.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_35.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:46:10 (11.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_35.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:46:10--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_36.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_36.edf’
#
# physionet.org/files 100%[===================>]  40.44M  42.1MB/s    in 1.0s
#
# 2022-02-13 16:46:11 (42.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_36.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:11--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_36.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_36.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:46:11 (11.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_36.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:46:11--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_37.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_37.edf’
#
# physionet.org/files 100%[===================>]  40.44M  48.6MB/s    in 0.8s
#
# 2022-02-13 16:46:12 (48.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_37.edf’ saved [42399744/42399744]
#
# --2022-02-13 16:46:12--  https://physionet.org/files/chbmit/1.0.0/chb03/chb03_38.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_38.edf’
#
# physionet.org/files 100%[===================>]  40.44M  51.7MB/s    in 0.8s
#
# 2022-02-13 16:46:13 (51.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb03/chb03_38.edf’ saved [42399744/42399744]
#
# FINISHED --2022-02-13 16:46:13--
# Total wall clock time: 1m 0s
# Downloaded: 47 files, 1.5G in 57s (26.9 MB/s)

# %%
# !wget -r -N -c -np https://physionet.org/files/chbmit/1.0.0/chb04/
# Out:
# --2022-02-13 16:46:21--  https://physionet.org/files/chbmit/1.0.0/chb04/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/index.html’
#
# physionet.org/files     [ <=>                ]   5.52K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2022-02-13 16:46:21 (224 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/index.html’ saved [5655]
#
# Loading robots.txt; please ignore errors.
# --2022-02-13 16:46:21--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2022-02-13 16:46:21--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04-summary.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5645 (5.5K) [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04-summary.txt’
#
# physionet.org/files 100%[===================>]   5.51K  --.-KB/s    in 0s
#
# 2022-02-13 16:46:21 (730 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04-summary.txt’ saved [5645/5645]
#
# --2022-02-13 16:46:21--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_01.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 169556992 (162M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_01.edf’
#
# physionet.org/files 100%[===================>] 161.70M  52.1MB/s    in 3.1s
#
# 2022-02-13 16:46:25 (52.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_01.edf’ saved [169556992/169556992]
#
# --2022-02-13 16:46:25--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_02.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 169580544 (162M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_02.edf’
#
# physionet.org/files 100%[===================>] 161.72M  52.5MB/s    in 3.1s
#
# 2022-02-13 16:46:28 (52.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_02.edf’ saved [169580544/169580544]
#
# --2022-02-13 16:46:28--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_03.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 169580544 (162M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_03.edf’
#
# physionet.org/files 100%[===================>] 161.72M  55.8MB/s    in 2.9s
#
# 2022-02-13 16:46:31 (55.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_03.edf’ saved [169580544/169580544]
#
# --2022-02-13 16:46:31--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_04.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 169580544 (162M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_04.edf’
#
# physionet.org/files 100%[===================>] 161.72M  57.5MB/s    in 2.8s
#
# 2022-02-13 16:46:34 (57.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_04.edf’ saved [169580544/169580544]
#
# --2022-02-13 16:46:34--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_05.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 112302080 (107M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_05.edf’
#
# physionet.org/files 100%[===================>] 107.10M  56.2MB/s    in 1.9s
#
# 2022-02-13 16:46:36 (56.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_05.edf’ saved [112302080/112302080]
#
# --2022-02-13 16:46:36--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_05.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_05.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:46:36 (8.51 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_05.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:46:36--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_06.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 169580544 (162M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_06.edf’
#
# physionet.org/files 100%[===================>] 161.72M  55.0MB/s    in 2.9s
#
# 2022-02-13 16:46:39 (55.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_06.edf’ saved [169580544/169580544]
#
# --2022-02-13 16:46:39--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_07.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92117248 (88M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_07.edf’
#
# physionet.org/files 100%[===================>]  87.85M  56.3MB/s    in 1.6s
#
# 2022-02-13 16:46:40 (56.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_07.edf’ saved [92117248/92117248]
#
# --2022-02-13 16:46:40--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_08.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_08.edf’
#
# physionet.org/files 100%[===================>] 168.76M  41.9MB/s    in 4.1s
#
# 2022-02-13 16:46:44 (41.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_08.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:46:44--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_08.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_08.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 16:46:45 (8.12 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_08.edf.seizures’ saved [54/54]
#
# --2022-02-13 16:46:45--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_09.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_09.edf’
#
# physionet.org/files 100%[===================>] 168.76M  25.0MB/s    in 5.4s
#
# 2022-02-13 16:46:50 (31.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_09.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:46:50--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_10.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_10.edf’
#
# physionet.org/files 100%[===================>] 168.76M  15.6MB/s    in 9.0s
#
# 2022-02-13 16:46:59 (18.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_10.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:46:59--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_11.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59382016 (57M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_11.edf’
#
# physionet.org/files 100%[===================>]  56.63M  16.3MB/s    in 3.5s
#
# 2022-02-13 16:47:03 (16.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_11.edf’ saved [59382016/59382016]
#
# --2022-02-13 16:47:03--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_12.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 177199360 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_12.edf’
#
# physionet.org/files 100%[===================>] 168.99M  25.9MB/s    in 8.2s
#
# 2022-02-13 16:47:11 (20.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_12.edf’ saved [177199360/177199360]
#
# --2022-02-13 16:47:11--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_13.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176929024 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_13.edf’
#
# physionet.org/files 100%[===================>] 168.73M  25.3MB/s    in 5.4s
#
# 2022-02-13 16:47:16 (31.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_13.edf’ saved [176929024/176929024]
#
# --2022-02-13 16:47:16--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_14.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 177174784 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_14.edf’
#
# physionet.org/files 100%[===================>] 168.97M  28.6MB/s    in 5.9s
#
# 2022-02-13 16:47:22 (28.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_14.edf’ saved [177174784/177174784]
#
# --2022-02-13 16:47:22--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_15.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_15.edf’
#
# physionet.org/files 100%[===================>] 168.76M  30.7MB/s    in 5.6s
#
# 2022-02-13 16:47:28 (29.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_15.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:47:28--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_16.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_16.edf’
#
# physionet.org/files 100%[===================>] 168.76M  31.0MB/s    in 5.2s
#
# 2022-02-13 16:47:33 (32.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_16.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:47:33--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_17.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 168745216 (161M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_17.edf’
#
# physionet.org/files 100%[===================>] 160.93M  28.9MB/s    in 5.8s
#
# 2022-02-13 16:47:39 (27.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_17.edf’ saved [168745216/168745216]
#
# --2022-02-13 16:47:39--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_18.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 177260800 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_18.edf’
#
# physionet.org/files 100%[===================>] 169.05M  17.4MB/s    in 8.6s
#
# 2022-02-13 16:47:48 (19.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_18.edf’ saved [177260800/177260800]
#
# --2022-02-13 16:47:48--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_19.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_19.edf’
#
# physionet.org/files 100%[===================>] 168.76M  17.7MB/s    in 10s
#
# 2022-02-13 16:47:58 (16.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_19.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:47:58--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_21.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_21.edf’
#
# physionet.org/files 100%[===================>] 168.76M  22.9MB/s    in 8.4s
#
# 2022-02-13 16:48:07 (20.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_21.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:48:07--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_22.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_22.edf’
#
# physionet.org/files 100%[===================>] 168.76M  39.3MB/s    in 4.7s
#
# 2022-02-13 16:48:11 (35.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_22.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:48:11--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_23.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 131291392 (125M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_23.edf’
#
# physionet.org/files 100%[===================>] 125.21M  54.5MB/s    in 2.3s
#
# 2022-02-13 16:48:14 (54.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_23.edf’ saved [131291392/131291392]
#
# --2022-02-13 16:48:14--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_24.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 177027328 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_24.edf’
#
# physionet.org/files 100%[===================>] 168.83M  38.2MB/s    in 4.1s
#
# 2022-02-13 16:48:18 (41.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_24.edf’ saved [177027328/177027328]
#
# --2022-02-13 16:48:18--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_25.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_25.edf’
#
# physionet.org/files 100%[===================>] 168.76M  45.1MB/s    in 3.8s
#
# 2022-02-13 16:48:22 (44.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_25.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:48:22--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_26.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_26.edf’
#
# physionet.org/files 100%[===================>] 168.76M  43.2MB/s    in 3.9s
#
# 2022-02-13 16:48:26 (43.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_26.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:48:26--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_27.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 177285376 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_27.edf’
#
# physionet.org/files 100%[===================>] 169.07M  46.6MB/s    in 3.6s
#
# 2022-02-13 16:48:29 (46.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_27.edf’ saved [177285376/177285376]
#
# --2022-02-13 16:48:29--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_28.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 177236224 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_28.edf’
#
# physionet.org/files 100%[===================>] 169.03M  36.6MB/s    in 4.3s
#
# 2022-02-13 16:48:34 (39.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_28.edf’ saved [177236224/177236224]
#
# --2022-02-13 16:48:34--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_28.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_28.edf.seizures’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2022-02-13 16:48:34 (10.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_28.edf.seizures’ saved [70/70]
#
# --2022-02-13 16:48:34--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_29.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176990464 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_29.edf’
#
# physionet.org/files 100%[===================>] 168.79M  45.0MB/s    in 3.8s
#
# 2022-02-13 16:48:38 (44.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_29.edf’ saved [176990464/176990464]
#
# --2022-02-13 16:48:38--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_30.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_30.edf’
#
# physionet.org/files 100%[===================>] 168.76M  36.7MB/s    in 4.3s
#
# 2022-02-13 16:48:42 (39.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_30.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:48:42--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_31.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_31.edf’
#
# physionet.org/files 100%[===================>] 168.76M  36.5MB/s    in 4.5s
#
# 2022-02-13 16:48:47 (37.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_31.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:48:47--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_32.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_32.edf’
#
# physionet.org/files 100%[===================>] 168.76M  27.2MB/s    in 6.4s
#
# 2022-02-13 16:48:53 (26.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_32.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:48:53--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_33.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_33.edf’
#
# physionet.org/files 100%[===================>] 168.76M  27.9MB/s    in 6.2s
#
# 2022-02-13 16:48:59 (27.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_33.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:48:59--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_34.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_34.edf’
#
# physionet.org/files 100%[===================>] 168.76M  27.5MB/s    in 6.5s
#
# 2022-02-13 16:49:06 (25.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_34.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:49:06--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_35.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_35.edf’
#
# physionet.org/files 100%[===================>] 168.76M  25.0MB/s    in 6.6s
#
# 2022-02-13 16:49:13 (25.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_35.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:49:13--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_36.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_36.edf’
#
# physionet.org/files 100%[===================>] 168.76M  22.1MB/s    in 7.8s
#
# 2022-02-13 16:49:21 (21.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_36.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:49:21--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_37.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 68978944 (66M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_37.edf’
#
# physionet.org/files 100%[===================>]  65.78M  22.2MB/s    in 3.0s
#
# 2022-02-13 16:49:24 (22.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_37.edf’ saved [68978944/68978944]
#
# --2022-02-13 16:49:24--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_38.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_38.edf’
#
# physionet.org/files 100%[===================>] 168.76M  28.6MB/s    in 6.5s
#
# 2022-02-13 16:49:30 (25.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_38.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:49:30--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_39.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_39.edf’
#
# physionet.org/files 100%[===================>] 168.76M  43.0MB/s    in 4.1s
#
# 2022-02-13 16:49:34 (41.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_39.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:49:34--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_40.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_40.edf’
#
# physionet.org/files 100%[===================>] 168.76M  58.0MB/s    in 2.9s
#
# 2022-02-13 16:49:37 (58.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_40.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:49:37--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_41.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_41.edf’
#
# physionet.org/files 100%[===================>] 168.76M  59.7MB/s    in 2.8s
#
# 2022-02-13 16:49:40 (59.7 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_41.edf’ saved [176953600/176953600]
#
# --2022-02-13 16:49:40--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_42.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 71559424 (68M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_42.edf’
#
# physionet.org/files 100%[===================>]  68.24M  60.0MB/s    in 1.1s
#
# 2022-02-13 16:49:41 (60.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_42.edf’ saved [71559424/71559424]
#
# --2022-02-13 16:49:41--  https://physionet.org/files/chbmit/1.0.0/chb04/chb04_43.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176953600 (169M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_43.edf’
#
# physionet.org/files 100%[===================>] 168.76M  57.8MB/s    in 2.9s
#
# 2022-02-13 16:49:44 (57.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb04/chb04_43.edf’ saved [176953600/176953600]
#
# FINISHED --2022-02-13 16:49:44--
# Total wall clock time: 3m 23s
# Downloaded: 47 files, 6.4G in 3m 20s (32.7 MB/s)

# %%
# !wget -r -N -c -np https://physionet.org/files/chbmit/1.0.0/chb05/
# Out:
# --2022-02-13 17:14:42--  https://physionet.org/files/chbmit/1.0.0/chb05/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/index.html’
#
# physionet.org/files     [ <=>                ]   5.43K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2022-02-13 17:14:43 (150 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/index.html’ saved [5556]
#
# Loading robots.txt; please ignore errors.
# --2022-02-13 17:14:43--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2022-02-13 17:14:43--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05-summary.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4911 (4.8K) [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05-summary.txt’
#
# physionet.org/files 100%[===================>]   4.80K  --.-KB/s    in 0s
#
# 2022-02-13 17:14:43 (744 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05-summary.txt’ saved [4911/4911]
#
# --2022-02-13 17:14:43--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_01.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42517504 (41M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_01.edf’
#
# physionet.org/files 100%[===================>]  40.55M  30.4MB/s    in 1.3s
#
# 2022-02-13 17:14:44 (30.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_01.edf’ saved [42517504/42517504]
#
# --2022-02-13 17:14:44--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_02.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_02.edf’
#
# physionet.org/files 100%[===================>]  40.44M  44.9MB/s    in 0.9s
#
# 2022-02-13 17:14:45 (44.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_02.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:45--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_03.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_03.edf’
#
# physionet.org/files 100%[===================>]  40.44M  34.5MB/s    in 1.2s
#
# 2022-02-13 17:14:46 (34.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_03.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:46--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_04.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_04.edf’
#
# physionet.org/files 100%[===================>]  40.44M  36.6MB/s    in 1.1s
#
# 2022-02-13 17:14:48 (36.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_04.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:48--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_05.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_05.edf’
#
# physionet.org/files 100%[===================>]  40.44M  39.5MB/s    in 1.0s
#
# 2022-02-13 17:14:49 (39.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_05.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:49--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_06.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_06.edf’
#
# physionet.org/files 100%[===================>]  40.44M  41.1MB/s    in 1.0s
#
# 2022-02-13 17:14:50 (41.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_06.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:50--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_06.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_06.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 17:14:50 (13.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_06.edf.seizures’ saved [54/54]
#
# --2022-02-13 17:14:50--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_07.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_07.edf’
#
# physionet.org/files 100%[===================>]  40.44M  43.3MB/s    in 0.9s
#
# 2022-02-13 17:14:51 (43.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_07.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:51--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_08.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_08.edf’
#
# physionet.org/files 100%[===================>]  40.44M  43.5MB/s    in 0.9s
#
# 2022-02-13 17:14:52 (43.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_08.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:52--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_09.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_09.edf’
#
# physionet.org/files 100%[===================>]  40.44M  44.3MB/s    in 0.9s
#
# 2022-02-13 17:14:53 (44.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_09.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:53--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_10.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_10.edf’
#
# physionet.org/files 100%[===================>]  40.44M  43.6MB/s    in 0.9s
#
# 2022-02-13 17:14:54 (43.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_10.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:54--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_11.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_11.edf’
#
# physionet.org/files 100%[===================>]  40.44M  38.1MB/s    in 1.1s
#
# 2022-02-13 17:14:55 (38.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_11.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:55--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_12.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_12.edf’
#
# physionet.org/files 100%[===================>]  40.44M  44.9MB/s    in 0.9s
#
# 2022-02-13 17:14:56 (44.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_12.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:56--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_13.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_13.edf’
#
# physionet.org/files 100%[===================>]  40.44M  42.4MB/s    in 1.0s
#
# 2022-02-13 17:14:57 (42.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_13.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:57--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_13.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_13.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 17:14:57 (14.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_13.edf.seizures’ saved [54/54]
#
# --2022-02-13 17:14:57--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_14.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_14.edf’
#
# physionet.org/files 100%[===================>]  40.44M  39.0MB/s    in 1.0s
#
# 2022-02-13 17:14:58 (39.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_14.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:58--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_15.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_15.edf’
#
# physionet.org/files 100%[===================>]  40.44M  39.4MB/s    in 1.0s
#
# 2022-02-13 17:14:59 (39.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_15.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:14:59--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_16.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_16.edf’
#
# physionet.org/files 100%[===================>]  40.44M  35.1MB/s    in 1.2s
#
# 2022-02-13 17:15:00 (35.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_16.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:00--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_16.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_16.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 17:15:01 (8.73 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_16.edf.seizures’ saved [54/54]
#
# --2022-02-13 17:15:01--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_17.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_17.edf’
#
# physionet.org/files 100%[===================>]  40.44M  39.1MB/s    in 1.0s
#
# 2022-02-13 17:15:02 (39.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_17.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:02--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_17.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_17.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 17:15:02 (9.07 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_17.edf.seizures’ saved [54/54]
#
# --2022-02-13 17:15:02--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_18.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_18.edf’
#
# physionet.org/files 100%[===================>]  40.44M  35.1MB/s    in 1.2s
#
# 2022-02-13 17:15:03 (35.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_18.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:03--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_19.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_19.edf’
#
# physionet.org/files 100%[===================>]  40.44M  38.0MB/s    in 1.1s
#
# 2022-02-13 17:15:04 (38.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_19.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:04--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_20.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_20.edf’
#
# physionet.org/files 100%[===================>]  40.44M  36.5MB/s    in 1.1s
#
# 2022-02-13 17:15:05 (36.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_20.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:05--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_21.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_21.edf’
#
# physionet.org/files 100%[===================>]  40.44M  29.6MB/s    in 1.4s
#
# 2022-02-13 17:15:07 (29.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_21.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:07--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_22.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_22.edf’
#
# physionet.org/files 100%[===================>]  40.44M  33.1MB/s    in 1.2s
#
# 2022-02-13 17:15:08 (33.1 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_22.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:08--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_22.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54 [text/plain]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_22.edf.seizures’
#
# physionet.org/files 100%[===================>]      54  --.-KB/s    in 0s
#
# 2022-02-13 17:15:08 (8.22 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_22.edf.seizures’ saved [54/54]
#
# --2022-02-13 17:15:08--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_23.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_23.edf’
#
# physionet.org/files 100%[===================>]  40.44M  26.6MB/s    in 1.5s
#
# 2022-02-13 17:15:10 (26.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_23.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:10--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_24.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_24.edf’
#
# physionet.org/files 100%[===================>]  40.44M  25.0MB/s    in 1.6s
#
# 2022-02-13 17:15:11 (25.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_24.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:11--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_25.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_25.edf’
#
# physionet.org/files 100%[===================>]  40.44M  27.8MB/s    in 1.5s
#
# 2022-02-13 17:15:13 (27.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_25.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:13--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_26.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_26.edf’
#
# physionet.org/files 100%[===================>]  40.44M  30.3MB/s    in 1.3s
#
# 2022-02-13 17:15:14 (30.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_26.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:14--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_27.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_27.edf’
#
# physionet.org/files 100%[===================>]  40.44M  30.4MB/s    in 1.3s
#
# 2022-02-13 17:15:16 (30.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_27.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:16--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_28.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_28.edf’
#
# physionet.org/files 100%[===================>]  40.44M  27.9MB/s    in 1.4s
#
# 2022-02-13 17:15:17 (27.9 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_28.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:17--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_29.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_29.edf’
#
# physionet.org/files 100%[===================>]  40.44M  29.8MB/s    in 1.4s
#
# 2022-02-13 17:15:19 (29.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_29.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:19--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_30.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_30.edf’
#
# physionet.org/files 100%[===================>]  40.44M  30.8MB/s    in 1.3s
#
# 2022-02-13 17:15:20 (30.8 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_30.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:20--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_31.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_31.edf’
#
# physionet.org/files 100%[===================>]  40.44M  30.2MB/s    in 1.3s
#
# 2022-02-13 17:15:21 (30.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_31.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:21--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_32.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_32.edf’
#
# physionet.org/files 100%[===================>]  40.44M  27.5MB/s    in 1.5s
#
# 2022-02-13 17:15:23 (27.5 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_32.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:23--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_33.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_33.edf’
#
# physionet.org/files 100%[===================>]  40.44M  25.3MB/s    in 1.6s
#
# 2022-02-13 17:15:25 (25.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_33.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:25--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_34.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_34.edf’
#
# physionet.org/files 100%[===================>]  40.44M  26.0MB/s    in 1.6s
#
# 2022-02-13 17:15:26 (26.0 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_34.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:26--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_35.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_35.edf’
#
# physionet.org/files 100%[===================>]  40.44M  30.3MB/s    in 1.3s
#
# 2022-02-13 17:15:28 (30.3 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_35.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:28--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_36.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_36.edf’
#
# physionet.org/files 100%[===================>]  40.44M  31.2MB/s    in 1.3s
#
# 2022-02-13 17:15:29 (31.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_36.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:29--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_37.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_37.edf’
#
# physionet.org/files 100%[===================>]  40.44M  32.4MB/s    in 1.2s
#
# 2022-02-13 17:15:30 (32.4 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_37.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:30--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_38.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_38.edf’
#
# physionet.org/files 100%[===================>]  40.44M  31.2MB/s    in 1.3s
#
# 2022-02-13 17:15:32 (31.2 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_38.edf’ saved [42399744/42399744]
#
# --2022-02-13 17:15:32--  https://physionet.org/files/chbmit/1.0.0/chb05/chb05_39.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M) [application/octet-stream]
# Saving to: ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_39.edf’
#
# physionet.org/files 100%[===================>]  40.44M  31.6MB/s    in 1.3s
#
# 2022-02-13 17:15:33 (31.6 MB/s) - ‘physionet.org/files/chbmit/1.0.0/chb05/chb05_39.edf’ saved [42399744/42399744]
#
# FINISHED --2022-02-13 17:15:33--
# Total wall clock time: 51s
# Downloaded: 46 files, 1.5G in 47s (33.5 MB/s)

# %%
# !wget -r -N -c -np https://physionet.org/files/chbmit/1.0.0/chb06/

# %%
# !wget -r -N -c -np https://physionet.org/files/chbmit/1.0.0/chb07/

# %%
# !wget -r -N -c -np https://physionet.org/files/chbmit/1.0.0/ch
# Number of Seizures in File: 1
# Seizure Start Time: 3369 seconds
# Seizure End Time: 3378 seconds
#
# File Name: chb02_20.edf
# File Start Time: 14:50:53
# File End Time: 15:50:53
# Number of Seizures in File: 0
#
# File Name: chb02_21.edf
# File Start Time: 15:51:00
# File End Time: 16:51:00
# Number of Seizures in File: 0
#
# File Name: chb02_22.edf
# File Start Time: 16:51:08
# File End Time: 17:51:08
# Number of Seizures in File: 0
#
# File Name: chb02_23.edf
# File Start Time: 19:02:27
# File End Time: 20:02:27
# Number of Seizures in File: 0
#
# File Name: chb02_24.edf
# File Start Time: 20:02:40
# File End Time: 21:02:40
# Number of Seizures in File: 0
#
# File Name: chb02_25.edf
# File Start Time: 21:02:48
# File End Time: 22:02:48
# Number of Seizures in File: 0
#
# File Name: chb02_26.edf
# File Start Time: 22:02:55
# File End Time: 23:02:55
# Number of Seizures in File: 0
#
# File Name: chb02_27.edf
# File Start Time: 23:03:03
# File End Time: 24:03:03
# Number of Seizures in File: 0
#
# File Name: chb02_28.edf
# File Start Time: 00:03:10
# File End Time: 1:03:10
# Number of Seizures in File: 0
#
# File Name: chb02_29.edf
# File Start Time: 01:03:18
# File End Time: 2:03:18
# Number of Seizures in File: 0
#
# File Name: chb02_30.edf
# File Start Time: 02:03:25
# File End Time: 3:03:25
# Number of Seizures in File: 0
#
# File Name: chb02_31.edf
# File Start Time: 03:03:33
# File End Time: 4:03:33
# Number of Seizures in File: 0
#
# File Name: chb02_32.edf
# File Start Time: 04:03:40
# File End Time: 5:03:40
# Number of Seizures in File: 0
#
# File Name: chb02_33.edf
# File Start Time: 05:03:47
# File End Time: 6:03:47
# Number of Seizures in File: 0
#
# File Name: chb02_34.edf
# File Start Time: 06:03:55
# File End Time: 7:03:55
# Number of Seizures in File: 0
#
# File Name: chb02_35.edf
# File Start Time: 07:04:02
# File End Time: 8:04:02
# Number of Seizures in File: 0

# %%
# !pip install pyedflib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyedflib
#   Downloading pyEDFlib-0.1.30-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 34.3 MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.8/dist-packages (from pyedflib) (1.21.6)
# Installing collected packages: pyedflib
# Successfully installed pyedflib-0.1.30

# %%
from pyedflib import highlevel
import numpy as np
import matplotlib.pyplot as plt

# read an edf file
file2 = '/content/physionet.org/files/chbmit/1.0.0/chb01/chb01_04.edf'
signals, signal_headers, header = highlevel.read_edf(file2)

dft = np.fft.fft(signals, axis=1)

plt.subplot(1,2,1)
plt.plot(np.transpose(signals[0:3,:1000]))
plt.title('Raw signals')
plt.subplot(1,2,2)
plt.plot(np.transpose(dft[0:3,:1000]))
plt.title('Fourier transform')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
import os

path = '/content/physionet.org/files/chbmit/1.0.0'

edfFiles = []
txtFiles = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if file[-4:] == '.edf':
            edfFiles.append(os.path.join(r, file))
        elif file[-4:] == '.txt':
            txtFiles.append(os.path.join(r, file))

edfFiles = sorted(edfFiles)
txtFiles = sorted(txtFiles)

for f in edfFiles:
    print(f)

for f in txtFiles:
    print(f)
# Out:
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_01.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_02.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_03.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_04.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_05.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_06.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_07.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_08.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_09.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_10.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_11.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_12.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_13.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_14.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_15.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_16.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_17.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_18.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_19.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_20.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_21.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_22.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_23.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_24.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_25.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_26.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_27.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_29.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_30.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_31.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_32.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_33.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_34.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_36.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_37.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_38.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_39.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_40.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_41.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_42.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_43.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_46.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_01.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_02.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_03.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_04.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_05.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_06.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_07.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_08.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_09.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_10.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_11.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_12.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_13.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_14.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_15.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_16+.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_16.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_17.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_18.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_19.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_20.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_21.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_22.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_23.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_24.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_25.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_26.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_27.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_28.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_29.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_30.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_31.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_32.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_33.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_34.edf
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02_35.edf
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01-summary.txt
# /content/physionet.org/files/chbmit/1.0.0/chb02/chb02-summary.txt

# %%
from pyedflib import highlevel
import numpy as np
import matplotlib.pyplot as plt
import re
import matplotlib.pyplot as plt

def generateLabels(edfFileName):
  sub = edfFileName[48:53]
  filePath = '/content/physionet.org/files/chbmit/1.0.0/' + sub + '/' + sub + '-summary.txt'
  f = open(filePath, 'r')
  file_contents = f.read()

  file_list = file_contents.split('\n')
  sub = edfFileName[48:-4]
  sub = 'File Name: ' + sub + '.edf'
  ind = file_list.index(sub)

  seizures = list(map(int, re.findall(r'\d+', file_list[ind+3]) ))[0]
  start = []
  end   = []
  for i in range(seizures):
    start.append(list(map(int, re.findall(r'\d+', file_list[ind+2*i+4])))[0])
    end.append(list(map(int, re.findall(r'\d+', file_list[ind+2*i+5])))[0])
    # print(start, end)

  if seizures == 0:
    labels = np.zeros((3600))
  else:
    labels = np.ones((3600))
    labels[end[-1]:] *= 0
    for i in range(len(start)):
      labels[start[i]:end[i]] *= 2

  return labels

# %%
import random

totalData       = len(edfFiles)
# random.shuffle(edfFiles)
partition       = int(len(edfFiles) * 4/5)
edfFilesVal     = edfFiles[partition:]
edfFilesTrain   = edfFiles[:partition]
trainData       = len(edfFilesTrain)
valData         = len(edfFilesVal)

print(totalData, trainData, valData)
# Out:
# 78 62 16

# %%
from keras.utils import to_categorical

def stackDFTTrain(nbatch = 2):
  count = 0

  stackedDFT = np.zeros((1, 23, 256, 3))
  stackedLabels = np.zeros((1))
  rejected   = []

  while True:
    for f in edfFilesTrain:
      # print(f[48:-4])
      if stackedDFT.shape[0] >= nbatch*3600//3 + 1:
        print(stackedLabels.shape)
        if stackedDFT[1:nbatch*3600//3 + 1,:,:,:].shape == (3600*nbatch//3, 23, 256, 3) and to_categorical(stackedLabels[1:nbatch*3600//3 + 1], num_classes=3).shape == (3600*nbatch//3, 3):
          yield (stackedDFT[1:nbatch*3600//3 + 1,:,:,:],
                 to_categorical(stackedLabels[1:nbatch*3600//3 + 1], num_classes=3))
        stackedDFT = stackedDFT[nbatch*3600//3:,:,:,:]
        stackedLabels = stackedLabels[nbatch*3600:]
        print('extra', stackedDFT.shape, stackedLabels.shape)

      signals, signal_headers, header = highlevel.read_edf(f)
      if signals.shape[-1] % 3600 != 0 or signals.shape[0] != 23:
        rejected.append(f[48:-4])
        continue

      # if signals.shape != (23, 921600):
      #   rejected.append(f[54:59])
      #   continue

      count += 1
      print(f, signals.shape)
      s = int(signals.shape[1]/256)
      signals = np.reshape(signals, (23,256,3,s//3))
      signals = signals.transpose(3,0,1,2)
      stackedDFT = np.concatenate((stackedDFT, np.fft.fft(signals, axis=1)), axis=0)
      genLabels = generateLabels(f)
      stackedLabels = np.concatenate((stackedLabels, genLabels), axis=-1)



def stackDFTVal(nbatch = 1):
  count = 0

  stackedDFT = np.zeros((1, 23, 256, 3))
  stackedLabels = np.zeros((1))
  rejected   = []

  while True:

    for f in edfFilesVal:
      # print(f[54:-4])
      if stackedDFT.shape[0] >= nbatch*3600//3 + 1:
        # stackedDFT = np.reshape(stackedDFT, (1,)+stackedDFT.shape)
        # stackedDFT = np.reshape(stackedDFT, (1,23,256,3600
        # yield (np.reshape(stackedDFT[1:nbatch*3600//3 + 1,:,:,:],
        #                   (1,)+stackedDFT[1:nbatch*3600//3 + 1,:,:,:].shape),
        #        to_categorical(stackedLabels[1:nbatch*3600//3 + 1], num_classes=3))
        if stackedDFT[1:nbatch*3600//3 + 1,:,:,:].shape == (3600*nbatch//3, 23, 256, 3) and to_categorical(stackedLabels[1:nbatch*3600//3 + 1], num_classes=3).shape == (3600*nbatch//3, 3):
          yield (stackedDFT[1:nbatch*3600//3 + 1,:,:,:],
                 to_categorical(stackedLabels[1:nbatch*3600//3 + 1], num_classes=3))
        stackedDFT = stackedDFT[nbatch*3600//3:,:,:,:]
        stackedLabels = stackedLabels[nbatch*3600:]

      signals, signal_headers, header = highlevel.read_edf(f)
      if signals.shape[-1] % 3600 != 0 or signals.shape[0] != 23:
        rejected.append(f[48:-4])
        continue

      # if signals.shape != (23, 921600):
      #   rejected.append(f[54:59])
      #   continue
      count += 1
      print(f, signals.shape)
      s = int(signals.shape[1]/256)
      signals = np.reshape(signals, (23,256,3,s//3))
      signals = signals.transpose(3,0,1,2)
      stackedDFT = np.concatenate((stackedDFT, np.fft.fft(signals, axis=1)), axis=0)
      genLabels = generateLabels(f)
      stackedLabels = np.concatenate((stackedLabels, genLabels), axis=-1)

# %%
from keras.callbacks import Callback

# when accuracy reaches ACCURACY_THRESHOLD
ACCURACY_THRESHOLD = 0.95

class myCallback(Callback):
	def on_epoch_end(self, epoch, logs={}):
		if(logs.get('acc') > ACCURACY_THRESHOLD):
			print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))
			self.model.stop_training = True

# Instantiate a callback object
callbacks = myCallback()

# %%
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout, AveragePooling2D
from keras.utils import to_categorical

nBatch = 2

in1 = Input(shape=(23, 256, 3))
c1 = Conv2D(16, (5,5), activation='relu')(in1)
# m1 = MaxPooling2D()(c1)
m1 = AveragePooling2D()(c1)
# c2 = Conv2D(128, (5,5), activation='relu')(m1)
# # m2 = MaxPooling2D()(c2)
# d1 = Dropout(0.7)(c2)
# c3 = Conv2D(256, (5,5), activation='relu')(d1)
# # m3 = MaxPooling2D()(c3)
# d2 = Dropout(0.8)(c3)
# # c4 = Conv2D(64, (3,3), activation='relu')(d2)
# # m4 = MaxPooling2D()(c4)
# fl = Flatten()(d2)
# d1 = Dense(64, activation='relu')(fl)
# d2 = Dense(16, activation='relu')(d1)
# o = Dense(921600*nBatch, activation='softmax')(m1)
fl = Flatten()(m1)
# d1 = Dense(4, activation='relu')(fl)
o = Dense(3, activation='sigmoid')(fl)

model = Model(inputs=in1, outputs=o)
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 23, 256, 3)]      0
#
#  conv2d (Conv2D)             (None, 19, 252, 16)       1216
#
#  average_pooling2d (AverageP  (None, 9, 126, 16)       0
#  ooling2D)
#
#  flatten (Flatten)           (None, 18144)             0
#
#  dense (Dense)               (None, 3)                 54435
#
# =================================================================
# Total params: 55,651
# Trainable params: 55,651
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer = 'sgd', loss = 'categorical_crossentropy', metrics=['acc'])
# stepsTrain = int(len(edfFiles)/nBatch * 11/15)
# stepsVal = int(len(edfFiles)/nBatch * 4/15)
testSteps = int(trainData/(16*8))
valSteps = int(valData/16)
history_cnn = model.fit_generator(generator = stackDFTTrain(),
                                  steps_per_epoch = testSteps,
                                  epochs = 3,
                                  validation_data = stackDFTVal(),
                                  validation_steps = valSteps)
                                  # callbacks=[callbacks])
# Out:
# <ipython-input-14-082993573b2d>:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_cnn = model.fit_generator(generator = stackDFTTrain(),
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_01.edf (23, 921600)
# /content/physionet.org/files/chbmit/1.0.0/chb01/chb01_02.edf (23, 921600)
# (7201,)
# Epoch 1/3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-082993573b2d> in <module>
#       4 testSteps = int(trainData/(16*8))
#       5 valSteps = int(valData/16)
# ----> 6 history_cnn = model.fit_generator(generator = stackDFTTrain(),
#       7                                   steps_per_epoch = testSteps,
#       8                                   epochs = 3,
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2258         'Please use `Model.fit`, which supports generators.',
#    2259         stacklevel=2)
# -> 2260     return self.fit(
#    2261         generator,
#    2262         steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1418         logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1419         if logs is None:
# -> 1420           raise ValueError('Unexpected result of `train_function` '
#    1421                            '(Empty logs). Please use '
#    1422                            '`Model.compile(..., run_eagerly=True)`, or '
#
# ValueError: Unexpected result of `train_function` (Empty logs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.

# %%
import matplotlib.pyplot as pyplot

loss = history_cnn.history['loss']
val_loss = history_cnn.history['val_loss']
epochs = range(1, len(loss) + 1)
pyplot.grid()
pyplot.plot(epochs, loss, '*y-', label='Training loss')
pyplot.plot(epochs, val_loss, '*r-', label='Validation loss')
pyplot.title('Training and validation loss')
pyplot.xlabel('Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()

pyplot.grid()
acc = history_cnn.history['acc']
val_acc = history_cnn.history['val_acc']
epochs = range(1, len(loss) + 1)
pyplot.plot(epochs, acc, '*y-', label='Training Accuracy')
pyplot.plot(epochs, val_acc, '*r-', label='Validation Accuracy')
pyplot.title('Training and validation Accuracies')
pyplot.xlabel('Epochs')
pyplot.ylabel('Loss')
pyplot.legend()
pyplot.show()

# %%
history_cnn.history

# %%
#pip uninstall keras
#!pip install keras==2.1.3
